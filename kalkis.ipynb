# %%
import numpy as np

print(0.8*((10**(-3))/(5*10**(-3)))**(1/2)*0.1)
# Out:
# 0.03577708763999664

# %%
import matplotlib.pyplot as plt

xs = np.linspace(0,1,500)
y = lambda x : x**3 -3/2*(x**2)+1/2*x
ys = y(xs)

plt.plot(xs,ys)
plt.show()
